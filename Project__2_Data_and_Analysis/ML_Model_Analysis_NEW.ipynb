# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots

from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import scipy.stats

# %%
data = pd.read_csv('Sold_And_Stats_Edited_New_a.csv')
data.head()
# Out:
#    Listing Number  Street Number Street Number Modifier Street Direction  \
# 0          825199           1118                    NaN              NaN
# 1          902993          12805                    NaN              NaN
# 2         1072254            810                    NaN              NaN
# 3         1106354           8735                    NaN              NaN
# 4         1110111          10403                    NaN              NaN
#
#   Street Name Street Suffix Street Post Direction     City State  Zip Code  \
# 0        Alki           Ave                    SW  Seattle    WA     98116
# 1        78th           Ave                     S  Seattle    WA     98178
# 2        34th           Ave                   NaN  Seattle    WA     98122
# 3         1st           Ave                    NW  Seattle    WA     98117
# 4        15th           Ave                   NaN  Seattle    WA     98125
#
#    ... Bathrooms  Bedrooms  Lot Square Footage   Listing Price  Selling Price  \
# 0  ...       0.0         3               4080.0      1900000.0      1500000.0
# 1  ...       0.0         0              10500.0       159000.0       155000.0
# 2  ...       0.0         0               4600.0       650000.0       650000.0
# 3  ...       0.0         0               6350.0       410000.0       448000.0
# 4  ...       0.0         0               6120.0       498000.0       475000.0
#
#    Sold to List Price Percentage  Square Footage    Style Code Property Type  \
# 0                      78.947368            1000  10 - 1 Story         House
# 1                      97.484277             580  10 - 1 Story         House
# 2                     100.000000            1060  10 - 1 Story         House
# 3                     109.268293             870  10 - 1 Story         House
# 4                      95.381526            1550  10 - 1 Story         House
#
#      Selling Date
# 0   5/1/2017 0:00
# 1  3/21/2018 0:00
# 2   5/5/2017 0:00
# 3  5/16/2017 0:00
# 4  5/15/2017 0:00
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57654 entries, 0 to 57653
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Listing Number                 57654 non-null  int64
#  1   Street Number                  57654 non-null  int64
#  2   Street Number Modifier         2257 non-null   object
#  3   Street Direction               17249 non-null  object
#  4   Street Name                    57654 non-null  object
#  5   Street Suffix                  55733 non-null  object
#  6   Street Post Direction          34223 non-null  object
#  7   City                           57654 non-null  object
#  8   State                          57654 non-null  object
#  9   Zip Code                       57654 non-null  int64
#  10  Area                           57654 non-null  object
#  11  Bathrooms                      57654 non-null  float64
#  12  Bedrooms                       57654 non-null  int64
#  13  Lot Square Footage             56373 non-null  float64
#  14  Listing Price                  57654 non-null  float64
#  15  Selling Price                  57654 non-null  float64
#  16  Sold to List Price Percentage  57654 non-null  float64
#  17  Square Footage                 57654 non-null  int64
#  18  Style Code                     57654 non-null  object
#  19  Property Type                  57654 non-null  object
#  20  Selling Date                   57654 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 9.2+ MB

# %%
#Drop un-needed columns

data.drop(['Listing Number', 'Street Number', 'Street Number Modifier', 'Street Direction', 'Street Name', 'Street Suffix', 'Street Post Direction', 'City', 'State', 'Area', 'Selling Date','Style Code', 'Listing Price'], axis=1,inplace=True)

# %%
data.head()
# Out:
#    Zip Code  Bathrooms  Bedrooms  Lot Square Footage   Selling Price  \
# 0     98116        0.0         3               4080.0      1500000.0
# 1     98178        0.0         0              10500.0       155000.0
# 2     98122        0.0         0               4600.0       650000.0
# 3     98117        0.0         0               6350.0       448000.0
# 4     98125        0.0         0               6120.0       475000.0
#
#    Sold to List Price Percentage  Square Footage Property Type
# 0                      78.947368            1000         House
# 1                      97.484277             580         House
# 2                     100.000000            1060         House
# 3                     109.268293             870         House
# 4                      95.381526            1550         House

# %%
data.dtypes
# Out:
# Zip Code                           int64
# Bathrooms                        float64
# Bedrooms                           int64
# Lot Square Footage               float64
# Selling Price                    float64
# Sold to List Price Percentage    float64
# Square Footage                     int64
# Property Type                     object
# dtype: object

# %%
#Data cleaning

data.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
data.dropna(subset=["Bathrooms", "Bedrooms"], how="all", inplace=True)

# %%
data.dropna(how='any', inplace=True)

# %%
data = data.fillna(0)

# %%
data[["Bathrooms", "Bedrooms", "Selling Price"]] = data[["Bedrooms", "Bathrooms", "Selling Price"]].apply(pd.to_numeric)

# %%
data = data.astype({"Bathrooms": int, "Bedrooms": int, "Selling Price": int})

# %%
PropertyType = {'House': 1,
                'Condo': 2,
                'Townhouse': 3,
               }

# %%
data.replace({"Property Type": PropertyType}, regex=True, inplace=True)

# %%
data = data.astype({"Property Type": int})

# %%
data = data.astype({"Zip Code": str})

# %%
data.head()
# Out:
#   Zip Code  Bathrooms  Bedrooms  Lot Square Footage   Selling Price  \
# 0    98116          3         0               4080.0        1500000
# 1    98178          0         0              10500.0         155000
# 2    98122          0         0               4600.0         650000
# 3    98117          0         0               6350.0         448000
# 4    98125          0         0               6120.0         475000
#
#    Sold to List Price Percentage  Square Footage  Property Type
# 0                      78.947368            1000              1
# 1                      97.484277             580              1
# 2                     100.000000            1060              1
# 3                     109.268293             870              1
# 4                      95.381526            1550              1

# %%
data.dtypes
# Out:
# Zip Code                          object
# Bathrooms                          int32
# Bedrooms                           int32
# Lot Square Footage               float64
# Selling Price                      int32
# Sold to List Price Percentage    float64
# Square Footage                     int64
# Property Type                      int32
# dtype: object

# %%
data.head()
# Out:
#   Zip Code  Bathrooms  Bedrooms  Lot Square Footage   Selling Price  \
# 0    98116          3         0               4080.0        1500000
# 1    98178          0         0              10500.0         155000
# 2    98122          0         0               4600.0         650000
# 3    98117          0         0               6350.0         448000
# 4    98125          0         0               6120.0         475000
#
#    Sold to List Price Percentage  Square Footage  Property Type
# 0                      78.947368            1000              1
# 1                      97.484277             580              1
# 2                     100.000000            1060              1
# 3                     109.268293             870              1
# 4                      95.381526            1550              1

# %%
#DATA CLEANING

#data['Listing Price'] = data['Listing Price'].round(decimals=2)

# %%
#Houses where bedroom is 0

data.loc[(data['Bedrooms'] == 0)].head()
# Out:
#   Zip Code  Bathrooms  Bedrooms  Lot Square Footage   Selling Price  \
# 0    98116          3         0               4080.0        1500000
# 1    98178          0         0              10500.0         155000
# 2    98122          0         0               4600.0         650000
# 3    98117          0         0               6350.0         448000
# 4    98125          0         0               6120.0         475000
#
#    Sold to List Price Percentage  Square Footage  Property Type
# 0                      78.947368            1000              1
# 1                      97.484277             580              1
# 2                     100.000000            1060              1
# 3                     109.268293             870              1
# 4                      95.381526            1550              1

# %%
#Houses with 0 bathrooms

data.loc[(data['Bathrooms'] == 0)].head()
# Out:
#   Zip Code  Bathrooms  Bedrooms  Lot Square Footage   Selling Price  \
# 1    98178          0         0              10500.0         155000
# 2    98122          0         0               4600.0         650000
# 3    98117          0         0               6350.0         448000
# 4    98125          0         0               6120.0         475000
# 7    98125          0         0               7563.0         370000
#
#    Sold to List Price Percentage  Square Footage  Property Type
# 1                      97.484277             580              1
# 2                     100.000000            1060              1
# 3                     109.268293             870              1
# 4                      95.381526            1550              1
# 7                      92.731830             700              1

# %%
#Check the outliers (most expensive)

data.sort_values(by=['Selling Price'],ascending=False).head()
# Out:
#       Zip Code  Bathrooms  Bedrooms  Lot Square Footage   Selling Price  \
# 32936    98122          4         6              50705.0       30750000
# 23147    98105          4         3              67106.0       14850000
# 13113    98112          4         4              32856.0       14275000
# 31817    98112          4         3              64981.0       13750000
# 13157    98112          6         6               9750.0       13300000
#
#        Sold to List Price Percentage  Square Footage  Property Type
# 32936                      87.857143            9791              1
# 23147                      99.000000            4620              1
# 13113                      85.223881            5612              1
# 31817                      91.666667            6750              1
# 13157                      95.717884            8703              1

# %%
#Check the outliers (cheapest)

data.loc[(data['Selling Price'] > 0)].sort_values(by=['Selling Price']).head()
# Out:
#       Zip Code  Bathrooms  Bedrooms  Lot Square Footage   Selling Price  \
# 32960    98102          0         0               4064.0          38000
# 32967    98109          0         0               7200.0          40000
# 34810    98168          1         1                  0.0          73000
# 33889    98178          1         1                  0.0          96000
# 33913    98188          1         1             292737.0         100000
#
#        Sold to List Price Percentage  Square Footage  Property Type
# 32960                      95.118899             168              2
# 32967                     100.000000             185              2
# 34810                     108.148148             680              2
# 33889                      96.048024             683              2
# 33913                     100.000000             602              2

# %%
#Check the outliers (widest sqft_living)

data.sort_values(by=['Square Footage'],ascending=False).head()
# Out:
#       Zip Code  Bathrooms  Bedrooms  Lot Square Footage   Selling Price  \
# 13161    98112          7         6              16874.0        6400000
# 13170    98177          8         8             194167.0        3600000
# 13164    98102          5         6              31000.0       10960000
# 32943    98112          5         6              10000.0        4850000
# 32949    98104          0         0                 10.0        7500000
#
#        Sold to List Price Percentage  Square Footage  Property Type
# 13161                      89.824561           12280              1
# 13170                      75.000000           11240              1
# 13164                      73.066667           11000              1
# 32943                     121.401752           10416              1
# 32949                      93.750000            9876              2

# %%
#Drop 0 values from rows

data = data[(data[['Bathrooms','Bedrooms','Square Footage']] != 0).all(axis=1)]

# %%
data.head()
# Out:
#     Zip Code  Bathrooms  Bedrooms  Lot Square Footage   Selling Price  \
# 132    98126          2         1               6120.0         415000
# 133    98102          1         1              12269.0        1800000
# 134    98136          2         1               4383.0         525000
# 135    98177          1         1               3333.0         429500
# 136    98118          3         1               7920.0         299950
#
#      Sold to List Price Percentage  Square Footage  Property Type
# 132                     118.588370             890              1
# 133                     100.000000             644              1
# 134                     100.000000             720              1
# 135                      95.657016             550              1
# 136                     100.000000            1320              1

# %%
#Correlation Check

features = data
encoder = LabelEncoder()
features['Zip Code'] = encoder.fit_transform(features['Zip Code'])

plt.figure(figsize=(20,15))
sns.heatmap(features.corr(), annot=True)
plt.title("Heatmap of all the Features", fontsize = 30);
plt.show()

# %%
#Split data to X for variable input, and y for target class

y = features['Selling Price']
X = features.drop(['Selling Price'],axis=1)

# %%
#Train test split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
##### LINEAR REGRESSION MODEL #####

reg = LinearRegression()
reg.fit(X_train, y_train)

print('coef of determination training ', reg.score(X_train, y_train))
print('coef of determination testing ', reg.score(X_test, y_test))
print()
reg_pred = list(reg.predict(X_test))
for i in reg_pred[0:10]:
  print('Prediction price of house', reg_pred.index(i)+1, ': $', i)
print()
for i in list(y_test[0:10]):
  print('Real price of house', list(y_test).index(i)+1, ': $', i)
print()
reg_mae = reg.predict(X_train)
print('Mean Absolute Error: ',mean_absolute_error(y_train, reg_mae))
mse = mean_squared_error(y_test,reg_pred)
print('Root Mean Square Error : ', np.sqrt(mse))
# Out:
# coef of determination training  0.592331995688957
# coef of determination testing  0.5622086975887339
#
# Prediction price of house 1 : $ 1594029.980166608
# Prediction price of house 2 : $ 1074330.6008948176
# Prediction price of house 3 : $ 638390.8130446181
# Prediction price of house 4 : $ 984583.0955590404
# Prediction price of house 5 : $ 479778.4564733767
# Prediction price of house 6 : $ 1569309.9829645883
# Prediction price of house 7 : $ 575078.1021648614
# Prediction price of house 8 : $ 1600724.5134409354
# Prediction price of house 9 : $ 470618.3382955092
# Prediction price of house 10 : $ 759189.8310744116
#
# Real price of house 1 : $ 2168000
# Real price of house 2 : $ 650000
# Real price of house 3 : $ 750000
# Real price of house 4 : $ 850000
# Real price of house 5 : $ 757000
# Real price of house 6 : $ 3050000
# Real price of house 7 : $ 585000
# Real price of house 8 : $ 1525000
# Real price of house 9 : $ 680000
# Real price of house 10 : $ 965000
#
# Mean Absolute Error:  199566.31942909834
# Root Mean Square Error :  394970.55919544183

# %%
#VISUALIZE LINEAR REGRESSION MODEL

reg_real_price = pd.DataFrame(y_test[:30]).reset_index(drop=True)
reg_pred_price = pd.DataFrame(reg_pred[:30], columns = ['predicted'])
reg_result = pd.concat([reg_real_price, reg_pred_price], axis=1) 
reg_result.plot(kind='bar') 

plt.rcParams["figure.figsize"] = (30, 15)
plt.title("Linear regression price comparison")
plt.xlabel('Sample') 
plt.ylabel('House Price') 
plt.show()

# %%
##### DECISION TREE MODEL #####

dt = DecisionTreeRegressor(max_depth=18)
dt.fit(X_train, y_train)

print('coef of determination training ',dt.score(X_train, y_train))
print('coef of determination testing ',dt.score(X_test, y_test))
print()
print('prediction')
dt_pred = list(dt.predict(X_test))
for i in dt_pred[0:10]:
  print('Prediction price of house', dt_pred.index(i)+1, ': $', i)
print()
for i in list(y_test[0:10]):
  print('Real price of house', list(y_test).index(i)+1, ': $', i)
print()
dt_mae = dt.predict(X_train)
print('Mean Absolute Error: ', mean_absolute_error(y_train, dt_mae))
mse = mean_squared_error(y_test,dt_pred)
print('Root Mean Square Error : ', np.sqrt(mse))
# Out:
# coef of determination training  0.9670753567684753
# coef of determination testing  0.5129786678381498
#
# prediction
# Prediction price of house 1 : $ 2710000.0
# Prediction price of house 2 : $ 778200.0
# Prediction price of house 3 : $ 849000.0
# Prediction price of house 4 : $ 790490.947368421
# Prediction price of house 5 : $ 708346.1538461539
# Prediction price of house 6 : $ 2800000.0
# Prediction price of house 7 : $ 686097.8571428572
# Prediction price of house 8 : $ 1080000.0
# Prediction price of house 9 : $ 735000.0
# Prediction price of house 10 : $ 834629.3333333334
#
# Real price of house 1 : $ 2168000
# Real price of house 2 : $ 650000
# Real price of house 3 : $ 750000
# Real price of house 4 : $ 850000
# Real price of house 5 : $ 757000
# Real price of house 6 : $ 3050000
# Real price of house 7 : $ 585000
# Real price of house 8 : $ 1525000
# Real price of house 9 : $ 680000
# Real price of house 10 : $ 965000
#
# Mean Absolute Error:  54081.37166502514
# Root Mean Square Error :  416586.46202123235

# %%
#VISUALIZE DECISION TREE

dt_real_price = pd.DataFrame(y_test[:30]).reset_index(drop=True)
dt_pred_price = pd.DataFrame(dt_pred[:30], columns = ['predicted'])
dt_result = pd.concat([dt_real_price, dt_pred_price], axis=1) 
dt_result.plot(kind='bar') 

plt.rcParams["figure.figsize"] = (30, 15)
plt.title("Decision Tree price comparison")
plt.xlabel('Sample') 
plt.ylabel('House Price') 
plt.show()

# %%
##### RANDOM FOREST MODEL #####

rf = RandomForestRegressor()
rf.fit(X_train, y_train)

print('coef of determination training ',rf.score(X_train, y_train))
print('coef of determination testing ',rf.score(X_test, y_test))
print()
print('prediction')
rf_pred = list(rf.predict(X_test))
for i in rf_pred[0:10]:
  print('Prediction price of house', rf_pred.index(i)+1, ': $', i)
print()
for i in list(y_test[0:10]):
  print('Real price of house', list(y_test).index(i)+1, ': $', i)
print()
rf_mae = rf.predict(X_train)
print('Mean Absolute Error: ', mean_absolute_error(y_train, rf_mae))

mse = mean_squared_error(y_test,rf_pred)
print('Root Mean Square Error : ', np.sqrt(mse))
# Out:
# coef of determination training  0.963706444752547
# coef of determination testing  0.6807799278683254
#
# prediction
# Prediction price of house 1 : $ 2217335.0
# Prediction price of house 2 : $ 694814.7
# Prediction price of house 3 : $ 743929.5
# Prediction price of house 4 : $ 848537.16
# Prediction price of house 5 : $ 706530.2816626957
# Prediction price of house 6 : $ 2902189.0
# Prediction price of house 7 : $ 621662.03
# Prediction price of house 8 : $ 1209692.98
# Prediction price of house 9 : $ 646475.0
# Prediction price of house 10 : $ 983967.11
#
# Real price of house 1 : $ 2168000
# Real price of house 2 : $ 650000
# Real price of house 3 : $ 750000
# Real price of house 4 : $ 850000
# Real price of house 5 : $ 757000
# Real price of house 6 : $ 3050000
# Real price of house 7 : $ 585000
# Real price of house 8 : $ 1525000
# Real price of house 9 : $ 680000
# Real price of house 10 : $ 965000
#
# Mean Absolute Error:  52150.61377730218
# Root Mean Square Error :  337268.86875666573

# %%
#VISUALIZE RANDOM FOREST MODEL

rf_real_price = pd.DataFrame(y_test[:30]).reset_index(drop=True)
rf_pred_price = pd.DataFrame(rf_pred[:30], columns = ['predicted'])
rf_result = pd.concat([rf_real_price, rf_pred_price], axis=1) 
rf_result.plot(kind='bar') 

plt.rcParams["figure.figsize"] = (30, 15)
plt.title("Random Forest price comparison")
plt.xlabel('Sample') 
plt.ylabel('House Price') 
plt.show()
